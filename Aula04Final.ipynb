# %%
from IPython.display import Image
from IPython.display import HTML
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as npr
import math
import pylab as pl

# %%
#Erro relativo e absoluto
m = (0.1/2112.9)*100
n = (0.1/5.3)*100
print(m)
print(n)
# Out:
# 0.0047328316531780965
# 1.886792452830189

# %%
A = np.linspace(2, 12, num = 100)

def func(t):
    return 10**(1-t)
def funcaonova(t):
    return (10**(1-t))*(0.5)

plt.plot(A,func(A))
plt.plot(A,funcaonova(A))
plt.show()
